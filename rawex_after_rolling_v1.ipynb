# %% [markdown]
# <a href="https://colab.research.google.com/github/iamksseo/colab/blob/master/rawex_after_rolling_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이타 가져오기

# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import os
import pandas as pd

os.chdir('/content/gdrive/MyDrive/AIOps/buildup-research/pinpoint/ExceptionCase/data')

data = pd.read_csv('rawex_after_rolling_update_5s.csv')

# %%
data.head()
# Out:
#                    endTime  ...     applicationId
# 0  2021-02-05 02:18:51.496  ...  CNSV_web_pc_real
# 1  2021-02-05 02:20:11.121  ...  CNSV_web_pc_real
# 2  2021-02-05 02:20:43.799  ...  CNSV_web_pc_real
# 3  2021-02-05 02:24:50.271  ...  CNSV_web_pc_real
# 4  2021-02-05 02:44:43.944  ...  CNSV_web_pc_real
#
# [5 rows x 22 columns]

# %%
data.tail()
# Out:
#                        endTime  ...     applicationId
# 24802  2021-02-25 00:56:03.755  ...  CNSV_web_pc_real
# 24803  2021-02-25 00:56:40.278  ...  CNSV_web_pc_real
# 24804  2021-02-25 00:58:42.709  ...  CNSV_web_pc_real
# 24805  2021-02-25 00:58:57.624  ...  CNSV_web_pc_real
# 24806  2021-02-25 00:59:36.323  ...  CNSV_web_pc_real
#
# [5 rows x 22 columns]
